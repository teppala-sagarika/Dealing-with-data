# %%
import pandas as pd;

# %%
info = {
    "Name" : ["Raj","Sagarika","Moukhi"],
    "CGPA" : [9.5,9.98,8.5]
}

df = pd.DataFrame(info)

print(df)
# Out:
#        Name  CGPA
# 0       Raj  9.50
# 1  Sagarika  9.98
# 2    Moukhi  8.50

# %%
df
# Out:
#        Name  CGPA
# 0       Raj  9.50
# 1  Sagarika  9.98
# 2    Moukhi  8.50
